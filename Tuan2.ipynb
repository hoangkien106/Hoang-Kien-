# %%
print("hello")
# Out:
# hello

# %%
name = input("Nhập tên của bạn :")
print(f"tên của bạn là:{name}")
# Out:
# tên của bạn là:kien

# %%
#W2A3
a = int(input(" Nhập số a : "))
b=  int(input(" Nhập số b : "))
print(f"Tổng của {a} và {b} là {a + b}")
print(f"Hiệu của {a} và {b} là {a - b}")
print(f"Tích của {a} và {b} là {a * b}")
print(f"Thương của {a} và {b} là {a / b}")
print(f"phần nguyên của {a} khi chia {b} là {a // b}")
print(f"Phần dư của {a} khi chia {b} là {a % b}")
# Out:
# Tổng của 5 và 3 là 8
# Hiệu của 5 và 3 là 2
# Tích của 5 và 3 là 15
# Thương của 5 và 3 là 1.6666666666666667
# phần nguyên của 5 khi chia 3 là 1
# Phần dư của 5 khi chia 3 là 2

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int, input().split())
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(f"{TB:.1f}")
# Out:
# 4.2

# %%
#W2A5
a, b = map(int,input().split())
print(f"a mũ b là : {a ** b}")
# Out:
# a mũ b là : 3125

# %%
#W2A6
print(ord('a'))
print(chr(97))
s = input ("")
print(chr(ord(s)-32))
# Out:
# 97
# a
# O

# %%
#W2A7
A = ((13 ** 2) * 3) + 5 
B = 13**2*3 + 5
print(A, B, sep= "=====")
# Out:
# 512=====512

# %%
#W2A8
c = float(input("Nhập độ C:"))
a = 9/5*c + 32
print(f"NHiệt độ F là:{a:.2f}")
# Out:
# NHiệt độ F là:89.60

# %%
#W2A9
X = int(input("Chiếc đồng hồ có giá :"))
a = X*3/10 + X*1/10 + X + 10
print(f"số tiền phải trả là:{a}")
# Out:
# số tiền phải trả là:150.0

# %%
#W2A10
names = input("Nhập ba người vào bàn phím:").split()
name3 = names[2]
name2 = names[1]
name1 = names[0]
print(f"Hi {name3},{name2} and {name1}")
# Out:
# Hi j,k and l

# %%
#w2A11
a = int(input("Nhập số giờ :"))
b = int(input("Nhập số phút:"))
c = a*3600 + b*60
print(f"số giờ , phút là {a},{b} và chuyển sang giây là {c} ")
# Out:
# số giờ , phút là 10,6 và chuyển sang giây là 36360

# %%
#W2A12
n = int(input("Rubik có độ dài cạnh là:"))
s = 6*n*n
print(f"số miếng dán cần dùng là: {s}")
# Out:
# số miếng dán cần dùng là: 150

# %%
#W2A13
a = int(input("Nhập số nguyên dương a :"))
b = int(input("Nhập số nguyên dương b :"))
c = (a*b) % 10
print(f"hàng đơn vị của phép tính tích giữa a và b là {c}")
# Out:
# hàng đơn vị của phép tính tích giữa a và b là 8

# %%
#W2A14
a, b = map(int,input("Nhập hai số :").split())
print(f"Hai số trước khi hoán đổi là: {a} và {b}")
a, b = b, a
print(f"Hai số sau khi hoán đổi là: {a} và {b}")
# Out:
# Hai số trước khi hoán đổi là: 2 và 3
# Hai số sau khi hoán đổi là: 3 và 2
